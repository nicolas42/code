# %%
import markov_chain_language_generator

markov_chain_language_generator.demo()
# Out:
# reading https://nschmidt-public.s3.ap-southeast-2.amazonaws.com/2701-0.txt ...
#
# ’mong the worlds blackberrying. Cook! ho, cook! and yet pulling for the fun of it; and Sir Clifford, because he was full of strangeness, and unaccountable to his flukes, and in the passage, he was at his sacrificial fire of shavings, I sallied out among them again directly in advance slid aside; and there is little of a triangular opening faced towards the bulwarks, and with fascinated eyes they awaited whatever magic might follow. But Starbuck looked away. With a broken bone, old Ahab has his too, if I’m not mistaken.—Aye, aye, sir, just through with that intent crossed the

# %%
import kmeans_clustering_algorithm

kmeans_clustering_algorithm.demo()
# Out:
# /Users/nick/everything/python/kmeans_clustering_algorithm.py:40: RuntimeWarning: covariance is not positive-semidefinite.
#   data1 = np.random.multivariate_normal(m1, cov1, 250)
# /Users/nick/everything/python/kmeans_clustering_algorithm.py:42: RuntimeWarning: covariance is not positive-semidefinite.
#   data3 = np.random.multivariate_normal(m3, cov3, 100)
