# %%
import make_a_story_with_a_markov_chain

make_a_story_with_a_markov_chain.demo()
# Out:
# globe; yea and dive straight through for ninety-six hours; when he quits the surface, the Sperm Whale’s tail to the Pequod’s keels had shot by them to have been of any sort whatsoever. Furthermore, you are now; that’s the stroke for a gate in the captain’s wick into; aye, we all sleep together in one hell—how was that? Oh! I don’t stand right on my legs. Coming afoul of that unfallen, western world, which to the furthest depths, the Sperm Whale) should have excited so little curiosity among the cleanliest things of that prudent isle were inclined to any monomaniac

# %%
import kmeans_clustering_algorithm

kmeans_clustering_algorithm.demo()
# Out:
# /Users/nick/everything/python/kmeans_clustering_algorithm.py:40: RuntimeWarning: covariance is not positive-semidefinite.
#   data1 = np.random.multivariate_normal(m1, cov1, 250)
# /Users/nick/everything/python/kmeans_clustering_algorithm.py:42: RuntimeWarning: covariance is not positive-semidefinite.
#   data3 = np.random.multivariate_normal(m3, cov3, 100)
